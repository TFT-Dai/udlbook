# %% [markdown]
# # **Notebook 8.1: MNIST_1D_Performance**
#
# This notebook runs a simple neural network on the MNIST1D dataset as in figure 8.2a. It uses code from https://github.com/greydanus/mnist1d to generate the data.
#
# Work through the cells below, running each cell in turn. In various places you will see the words "TODO". Follow the instructions at these places and make predictions about what is going to happen or write code to complete the functions.
#
# Contact me at udlbookmail@gmail.com if you find any mistakes or have any suggestions.

# %%
# Run this if you're in a Colab to install MNIST 1D repository
# %pip install git+https://github.com/greydanus/mnist1d
# Out:
# Collecting git+https://github.com/greydanus/mnist1d
#   Cloning https://github.com/greydanus/mnist1d to /tmp/pip-req-build-y7pj57vp
#   Running command git clone --filter=blob:none --quiet https://github.com/greydanus/mnist1d /tmp/pip-req-build-y7pj57vp
#   Resolved https://github.com/greydanus/mnist1d to commit 7878d96082abd200c546a07a4101fa90b30fdf7e
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# Requirement already satisfied: requests in /usr/local/lib/python3.12/dist-packages (from mnist1d==0.0.2.post16) (2.32.4)
# Requirement already satisfied: numpy in /usr/local/lib/python3.12/dist-packages (from mnist1d==0.0.2.post16) (2.0.2)
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.12/dist-packages (from mnist1d==0.0.2.post16) (3.10.0)
# Requirement already satisfied: scipy in /usr/local/lib/python3.12/dist-packages (from mnist1d==0.0.2.post16) (1.16.3)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib->mnist1d==0.0.2.post16) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.12/dist-packages (from matplotlib->mnist1d==0.0.2.post16) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.12/dist-packages (from matplotlib->mnist1d==0.0.2.post16) (4.63.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib->mnist1d==0.0.2.post16) (1.5.0)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.12/dist-packages (from matplotlib->mnist1d==0.0.2.post16) (26.2)
# Requirement already satisfied: pillow>=8 in /usr/local/lib/python3.12/dist-packages (from matplotlib->mnist1d==0.0.2.post16) (11.3.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib->mnist1d==0.0.2.post16) (3.3.2)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.12/dist-packages (from matplotlib->mnist1d==0.0.2.post16) (2.9.0.post0)
# Requirement already satisfied: charset_normalizer<4,>=2 in /usr/local/lib/python3.12/dist-packages (from requests->mnist1d==0.0.2.post16) (3.4.9)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.12/dist-packages (from requests->mnist1d==0.0.2.post16) (3.18)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.12/dist-packages (from requests->mnist1d==0.0.2.post16) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.12/dist-packages (from requests->mnist1d==0.0.2.post16) (2026.6.17)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.12/dist-packages (from python-dateutil>=2.7->matplotlib->mnist1d==0.0.2.post16) (1.17.0)
# Building wheels for collected packages: mnist1d
#   Building wheel for mnist1d (pyproject.toml) ... done
#   Created wheel for mnist1d: filename=mnist1d-0.0.2.post16-py3-none-any.whl size=15951 sha256=8624351ca5cdc45ed87def5ef9100acabe9cc9899d5b41ca9c126e6405dc3839
#   Stored in directory: /tmp/pip-ephem-wheel-cache-06vn_5qo/wheels/18/40/b6/29381fee9b4c80fdbc304d52bb065a7286bbcca5ca2b8737c0
# Successfully built mnist1d
# Installing collected packages: mnist1d
# Successfully installed mnist1d-0.0.2.post16

# %%
import torch, torch.nn as nn
from torch.utils.data import TensorDataset, DataLoader
from torch.optim.lr_scheduler import StepLR
import numpy as np
import matplotlib.pyplot as plt
import mnist1d

# %% [markdown]
# Let's generate a training and test dataset using the MNIST1D code.  The dataset gets saved as a .pkl file so it doesn't have to be regenerated each time.

# %%
args = mnist1d.data.get_dataset_args()
data = mnist1d.data.get_dataset(args, path='./mnist1d_data.pkl', download=False, regenerate=False)

# The training and test input and outputs are in
# data['x'], data['y'], data['x_test'], and data['y_test']
print("Examples in training set: {}".format(len(data['y'])))
print("Examples in test set: {}".format(len(data['y_test'])))
print("Length of each example: {}".format(data['x'].shape[-1]))
# Out:
# Did or could not load data from ./mnist1d_data.pkl. Rebuilding dataset...
# Examples in training set: 4000
# Examples in test set: 1000
# Length of each example: 40

# %%
D_i = 40    # Input dimensions
D_k = 100   # Hidden dimensions
D_o = 10    # Output dimensions
# TODO:
# Define a model with two hidden layers of size 100
# And ReLU activations between them
# Replace this line (see Figure 7.8 of book for help):
model = torch.nn.Sequential(torch.nn.Linear(D_i, D_o));


def weights_init(layer_in):
  # TODO:
  # Initialize the parameters with He initialization
  # Replace this line (see figure 7.8 of book for help)
  print("Initializing layer")


# Call the function you just defined
model.apply(weights_init)
# Out:
# Initializing layer
# Initializing layer
# Sequential(
#   (0): Linear(in_features=40, out_features=10, bias=True)
# )

# %%
# choose cross entropy loss function (equation 5.24)
loss_function = torch.nn.CrossEntropyLoss()
# construct SGD optimizer and initialize learning rate and momentum
optimizer = torch.optim.SGD(model.parameters(), lr = 0.05, momentum=0.9)
# object that decreases learning rate by half every 10 epochs
scheduler = StepLR(optimizer, step_size=10, gamma=0.5)
x_train = torch.tensor(data['x'].astype('float32'))
y_train = torch.tensor(data['y'].transpose().astype('int64'))
x_test= torch.tensor(data['x_test'].astype('float32'))
y_test = torch.tensor(data['y_test'].astype('int64'))

# load the data into a class that creates the batches
data_loader = DataLoader(TensorDataset(x_train,y_train), batch_size=100, shuffle=True, worker_init_fn=np.random.seed(1))

# Initialize model weights
model.apply(weights_init)

# loop over the dataset n_epoch times
n_epoch = 50
# store the loss and the % correct at each epoch
losses_train = np.zeros((n_epoch))
errors_train = np.zeros((n_epoch))
losses_test = np.zeros((n_epoch))
errors_test = np.zeros((n_epoch))

for epoch in range(n_epoch):
  # loop over batches
  for i, batch in enumerate(data_loader):
    # retrieve inputs and labels for this batch
    x_batch, y_batch = batch
    # zero the parameter gradients
    optimizer.zero_grad()
    # forward pass -- calculate model output
    pred = model(x_batch)
    # compute the loss
    loss = loss_function(pred, y_batch)
    # backward pass
    loss.backward()
    # SGD update
    optimizer.step()

  # Run whole dataset to get statistics -- normally wouldn't do this
  pred_train = model(x_train)
  pred_test = model(x_test)
  _, predicted_train_class = torch.max(pred_train.data, 1)
  _, predicted_test_class = torch.max(pred_test.data, 1)
  errors_train[epoch] = 100 - 100 * (predicted_train_class == y_train).float().sum() / len(y_train)
  errors_test[epoch]= 100 - 100 * (predicted_test_class == y_test).float().sum() / len(y_test)
  losses_train[epoch] = loss_function(pred_train, y_train).item()
  losses_test[epoch]= loss_function(pred_test, y_test).item()
  print(f'Epoch {epoch:5d}, train loss {losses_train[epoch]:.6f}, train error {errors_train[epoch]:3.2f},  test loss {losses_test[epoch]:.6f}, test error {errors_test[epoch]:3.2f}')

  # tell scheduler to consider updating learning rate
  scheduler.step()
# Out:
# Initializing layer
# Initializing layer
# Epoch     0, train loss 1.748740, train error 69.50,  test loss 1.766477, test error 72.30
# Epoch     1, train loss 1.681679, train error 66.03,  test loss 1.719819, test error 67.90
# Epoch     2, train loss 1.656223, train error 66.03,  test loss 1.685158, test error 68.30
# Epoch     3, train loss 1.636731, train error 64.53,  test loss 1.684536, test error 69.00
# Epoch     4, train loss 1.631626, train error 64.53,  test loss 1.680727, test error 69.10
# Epoch     5, train loss 1.626060, train error 64.12,  test loss 1.678636, test error 69.20
# Epoch     6, train loss 1.618069, train error 64.30,  test loss 1.662584, test error 68.20
# Epoch     7, train loss 1.618620, train error 64.10,  test loss 1.669292, test error 67.40
# Epoch     8, train loss 1.617369, train error 63.50,  test loss 1.674076, test error 68.20
# Epoch     9, train loss 1.613921, train error 64.72,  test loss 1.681292, test error 69.00
# Epoch    10, train loss 1.600777, train error 62.90,  test loss 1.656559, test error 67.80
# Epoch    11, train loss 1.598452, train error 62.97,  test loss 1.655019, test error 67.20
# Epoch    12, train loss 1.604700, train error 62.92,  test loss 1.657088, test error 67.40
# Epoch    13, train loss 1.597408, train error 62.55,  test loss 1.659810, test error 66.50
# Epoch    14, train loss 1.599818, train error 63.75,  test loss 1.663172, test error 68.20
# Epoch    15, train loss 1.595861, train error 62.53,  test loss 1.654994, test error 68.40
# Epoch    16, train loss 1.597604, train error 62.80,  test loss 1.664387, test error 68.00
# Epoch    17, train loss 1.594308, train error 62.80,  test loss 1.659018, test error 68.20
# Epoch    18, train loss 1.598404, train error 62.95,  test loss 1.662205, test error 65.70
# Epoch    19, train loss 1.599705, train error 63.62,  test loss 1.666988, test error 67.00
# Epoch    20, train loss 1.592171, train error 62.22,  test loss 1.654068, test error 67.70
# Epoch    21, train loss 1.590851, train error 62.28,  test loss 1.655639, test error 67.40
# Epoch    22, train loss 1.591213, train error 62.50,  test loss 1.655310, test error 67.50
# Epoch    23, train loss 1.591428, train error 62.40,  test loss 1.657053, test error 66.70
# Epoch    24, train loss 1.590867, train error 62.80,  test loss 1.653818, test error 67.20
# Epoch    25, train loss 1.591125, train error 62.55,  test loss 1.654634, test error 67.30
# Epoch    26, train loss 1.591396, train error 62.62,  test loss 1.657788, test error 68.50
# Epoch    27, train loss 1.590063, train error 62.22,  test loss 1.652689, test error 66.90
# Epoch    28, train loss 1.590963, train error 62.47,  test loss 1.657118, test error 67.50
# Epoch    29, train loss 1.590512, train error 62.62,  test loss 1.654661, test error 67.00
# Epoch    30, train loss 1.589484, train error 62.12,  test loss 1.654992, test error 67.10
# Epoch    31, train loss 1.589222, train error 62.20,  test loss 1.654203, test error 67.80
# Epoch    32, train loss 1.589097, train error 62.30,  test loss 1.654430, test error 67.40
# Epoch    33, train loss 1.588998, train error 62.28,  test loss 1.655613, test error 67.50
# Epoch    34, train loss 1.588901, train error 62.17,  test loss 1.655168, test error 67.00
# Epoch    35, train loss 1.588868, train error 62.22,  test loss 1.654683, test error 67.30
# Epoch    36, train loss 1.588822, train error 62.10,  test loss 1.656611, test error 67.50
# Epoch    37, train loss 1.588726, train error 62.17,  test loss 1.654436, test error 67.50
# Epoch    38, train loss 1.588786, train error 62.17,  test loss 1.655839, test error 67.60
# Epoch    39, train loss 1.588628, train error 62.47,  test loss 1.654996, test error 67.60
# Epoch    40, train loss 1.588547, train error 62.40,  test loss 1.654965, test error 67.60
# Epoch    41, train loss 1.588443, train error 62.42,  test loss 1.655113, test error 67.40
# Epoch    42, train loss 1.588452, train error 62.42,  test loss 1.655460, test error 66.90
# Epoch    43, train loss 1.588408, train error 62.33,  test loss 1.656125, test error 67.60
# Epoch    44, train loss 1.588362, train error 62.08,  test loss 1.654797, test error 66.70
# Epoch    45, train loss 1.588414, train error 62.17,  test loss 1.654818, test error 67.30
# Epoch    46, train loss 1.588335, train error 62.25,  test loss 1.655369, test error 67.60
# Epoch    47, train loss 1.588274, train error 62.40,  test loss 1.655149, test error 67.70
# Epoch    48, train loss 1.588284, train error 62.33,  test loss 1.655820, test error 67.50
# Epoch    49, train loss 1.588212, train error 62.25,  test loss 1.654686, test error 67.00

# %%
# Plot the results
fig, ax = plt.subplots()
ax.plot(errors_train,'r-',label='train')
ax.plot(errors_test,'b-',label='test')
ax.set_ylim(0,100); ax.set_xlim(0,n_epoch)
ax.set_xlabel('Epoch'); ax.set_ylabel('Error')
ax.set_title('TrainError %3.2f, Test Error %3.2f'%(errors_train[-1],errors_test[-1]))
ax.legend()
plt.show()

# Plot the results
fig, ax = plt.subplots()
ax.plot(losses_train,'r-',label='train')
ax.plot(losses_test,'b-',label='test')
ax.set_xlim(0,n_epoch)
ax.set_xlabel('Epoch'); ax.set_ylabel('Loss')
ax.set_title('Train loss %3.2f, Test loss %3.2f'%(losses_train[-1],losses_test[-1]))
ax.legend()
plt.show()

# %% [markdown]
# **TODO**
#
# Play with the model -- try changing the number of layers, hidden units, learning rate, batch size, momentum or anything else you like.  See if you can improve the test results.
#
# Is it a good idea to optimize the hyperparameters in this way?  Will the final result be a good estimate of the true test performance?

# %% [markdown]
# Ans: It is not a good idea to optimize the hyperparameters in this way. It's optimistically biased. Should do it on three way split -- Train, Validation and Test set.
