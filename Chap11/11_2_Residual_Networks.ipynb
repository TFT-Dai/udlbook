# %% [markdown]
# # **Notebook 11.2: Residual Networks**
#
# This notebook adapts the networks for MNIST1D to use residual connections.
#
# Work through the cells below, running each cell in turn. In various places you will see the words "TODO". Follow the instructions at these places and make predictions about what is going to happen or write code to complete the functions.
#
# Contact me at udlbookmail@gmail.com if you find any mistakes or have any suggestions.

# %%
# Run this if you're in a Colab to install MNIST 1D repository
# !pip install git+https://github.com/greydanus/mnist1d
# Out:
# Collecting git+https://github.com/greydanus/mnist1d
#   Cloning https://github.com/greydanus/mnist1d to /tmp/pip-req-build-717a_vcu
#   Running command git clone --filter=blob:none --quiet https://github.com/greydanus/mnist1d /tmp/pip-req-build-717a_vcu
#   Resolved https://github.com/greydanus/mnist1d to commit 7878d96082abd200c546a07a4101fa90b30fdf7e
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# Requirement already satisfied: requests in /usr/local/lib/python3.12/dist-packages (from mnist1d==0.0.2.post16) (2.32.4)
# Requirement already satisfied: numpy in /usr/local/lib/python3.12/dist-packages (from mnist1d==0.0.2.post16) (2.0.2)
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.12/dist-packages (from mnist1d==0.0.2.post16) (3.10.0)
# Requirement already satisfied: scipy in /usr/local/lib/python3.12/dist-packages (from mnist1d==0.0.2.post16) (1.16.3)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib->mnist1d==0.0.2.post16) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.12/dist-packages (from matplotlib->mnist1d==0.0.2.post16) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.12/dist-packages (from matplotlib->mnist1d==0.0.2.post16) (4.63.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib->mnist1d==0.0.2.post16) (1.5.0)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.12/dist-packages (from matplotlib->mnist1d==0.0.2.post16) (26.2)
# Requirement already satisfied: pillow>=8 in /usr/local/lib/python3.12/dist-packages (from matplotlib->mnist1d==0.0.2.post16) (11.3.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib->mnist1d==0.0.2.post16) (3.3.2)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.12/dist-packages (from matplotlib->mnist1d==0.0.2.post16) (2.9.0.post0)
# Requirement already satisfied: charset_normalizer<4,>=2 in /usr/local/lib/python3.12/dist-packages (from requests->mnist1d==0.0.2.post16) (3.4.9)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.12/dist-packages (from requests->mnist1d==0.0.2.post16) (3.18)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.12/dist-packages (from requests->mnist1d==0.0.2.post16) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.12/dist-packages (from requests->mnist1d==0.0.2.post16) (2026.6.17)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.12/dist-packages (from python-dateutil>=2.7->matplotlib->mnist1d==0.0.2.post16) (1.17.0)
# Building wheels for collected packages: mnist1d
#   Building wheel for mnist1d (pyproject.toml) ... done
#   Created wheel for mnist1d: filename=mnist1d-0.0.2.post16-py3-none-any.whl size=14665 sha256=f562415cd3b85768432f42ae872996ac97abe1b48a64fe808e3b3d036c5eaddf
#   Stored in directory: /tmp/pip-ephem-wheel-cache-w7a4vgau/wheels/18/40/b6/29381fee9b4c80fdbc304d52bb065a7286bbcca5ca2b8737c0
# Successfully built mnist1d
# Installing collected packages: mnist1d
# Successfully installed mnist1d-0.0.2.post16

# %%
import numpy as np
import os
import torch, torch.nn as nn
from torch.utils.data import TensorDataset, DataLoader
from torch.optim.lr_scheduler import StepLR
import matplotlib.pyplot as plt
import mnist1d
import random

# %%
args = mnist1d.data.get_dataset_args()
data = mnist1d.data.get_dataset(args, path='./mnist1d_data.pkl', download=False, regenerate=False)

# The training and test input and outputs are in
# data['x'], data['y'], data['x_test'], and data['y_test']
print("Examples in training set: {}".format(len(data['y'])))
print("Examples in test set: {}".format(len(data['y_test'])))
print("Length of each example: {}".format(data['x'].shape[-1]))
# Out:
# Did or could not load data from ./mnist1d_data.pkl. Rebuilding dataset...
# Examples in training set: 4000
# Examples in test set: 1000
# Length of each example: 40

# %%
# Load in the data
train_data_x = data['x'].transpose()
train_data_y = data['y']
val_data_x = data['x_test'].transpose()
val_data_y = data['y_test']
# Print out sizes
print("Train data: %d examples (columns), each of which has %d dimensions (rows)"%((train_data_x.shape[1],train_data_x.shape[0])))
print("Validation data: %d examples (columns), each of which has %d dimensions (rows)"%((val_data_x.shape[1],val_data_x.shape[0])))
# Out:
# Train data: 4000 examples (columns), each of which has 40 dimensions (rows)
# Validation data: 1000 examples (columns), each of which has 40 dimensions (rows)

# %% [markdown]
# Define the network

# %%
# There are 40 input dimensions and 10 output dimensions for this data
# The inputs correspond to the 40 offsets in the MNIST1D template.
D_i = 40
# The outputs correspond to the 10 digits
D_o = 10


# We will adapt this model to have residual connections around the linear layers
# This is the same model we used in practical 8.1, but we can't use the sequential
# class for residual networks (which aren't strictly sequential).  Hence, I've rewritten
# it as a model that inherits from a base class

import torch.nn.functional as F

class ResidualNetwork(torch.nn.Module):
  def __init__(self, input_size, output_size, hidden_size=100):
    super(ResidualNetwork, self).__init__()
    self.linear1 = nn.Linear(input_size, hidden_size)
    self.linear2 = nn.Linear(hidden_size, hidden_size)
    self.linear3 = nn.Linear(hidden_size, hidden_size)
    self.linear4 = nn.Linear(hidden_size, output_size)
    print("Initialized MLPBase model with {} parameters".format(self.count_params()))

  def count_params(self):
    return sum([p.view(-1).shape[0] for p in self.parameters()])

# TODO -- Add residual connections to this model
# The order of operations within each block should similar to figure 11.5b
# ie., linear1 first, ReLU+linear2 in first residual block, ReLU+linear3 in second residual block), linear4 at end
# Replace this function
  def forward(self, x):
    h1 = self.linear1(x)
    h2 = self.linear2(F.relu(h1)) + h1
    h3 = self.linear3(F.relu(h2)) + h2
    return self.linear4(h3)

# %%
# He initialization of weights
def weights_init(layer_in):
  if isinstance(layer_in, nn.Linear):
    nn.init.kaiming_uniform_(layer_in.weight)
    layer_in.bias.data.fill_(0.0)

# %%
#Define the model
model = ResidualNetwork(40, 10)

# choose cross entropy loss function (equation 5.24 in the loss notes)
loss_function = nn.CrossEntropyLoss()
# construct SGD optimizer and initialize learning rate and momentum
optimizer = torch.optim.SGD(model.parameters(), lr = 0.05, momentum=0.9)
# object that decreases learning rate by half every 20 epochs
scheduler = StepLR(optimizer, step_size=20, gamma=0.5)
# convert data to torch tensors
x_train = torch.tensor(train_data_x.transpose().astype('float32'))
y_train = torch.tensor(train_data_y.astype('long'))
x_val= torch.tensor(val_data_x.transpose().astype('float32'))
y_val = torch.tensor(val_data_y.astype('long'))

# load the data into a class that creates the batches
data_loader = DataLoader(TensorDataset(x_train,y_train), batch_size=100, shuffle=True, worker_init_fn=np.random.seed(1))

# Initialize model weights
model.apply(weights_init)

# loop over the dataset n_epoch times
n_epoch = 100
# store the loss and the % correct at each epoch
losses_train = np.zeros((n_epoch))
errors_train = np.zeros((n_epoch))
losses_val = np.zeros((n_epoch))
errors_val = np.zeros((n_epoch))

for epoch in range(n_epoch):
  # loop over batches
  for i, data in enumerate(data_loader):
    # retrieve inputs and labels for this batch
    x_batch, y_batch = data
    # zero the parameter gradients
    optimizer.zero_grad()
    # forward pass -- calculate model output
    pred = model(x_batch)
    # compute the loss
    loss = loss_function(pred, y_batch)
    # backward pass
    loss.backward()
    # SGD update
    optimizer.step()

  # Run whole dataset to get statistics -- normally wouldn't do this
  pred_train = model(x_train)
  pred_val = model(x_val)
  _, predicted_train_class = torch.max(pred_train.data, 1)
  _, predicted_val_class = torch.max(pred_val.data, 1)
  errors_train[epoch] = 100 - 100 * (predicted_train_class == y_train).float().sum() / len(y_train)
  errors_val[epoch]= 100 - 100 * (predicted_val_class == y_val).float().sum() / len(y_val)
  losses_train[epoch] = loss_function(pred_train, y_train).item()
  losses_val[epoch]= loss_function(pred_val, y_val).item()
  print(f'Epoch {epoch:5d}, train loss {losses_train[epoch]:.6f}, train error {errors_train[epoch]:3.2f},  val loss {losses_val[epoch]:.6f}, percent error {errors_val[epoch]:3.2f}')

  # tell scheduler to consider updating learning rate
  scheduler.step()
# Out:
# Initialized MLPBase model with 25310 parameters
# Epoch     0, train loss 1.608186, train error 61.75,  val loss 1.709508, percent error 65.00
# Epoch     1, train loss 1.211282, train error 46.15,  val loss 1.397271, percent error 53.20
# Epoch     2, train loss 1.035517, train error 39.67,  val loss 1.207929, percent error 45.10
# Epoch     3, train loss 0.958690, train error 36.28,  val loss 1.242483, percent error 45.20
# Epoch     4, train loss 0.815031, train error 31.30,  val loss 1.180156, percent error 43.40
# Epoch     5, train loss 0.764130, train error 29.47,  val loss 1.137916, percent error 41.50
# Epoch     6, train loss 0.683245, train error 24.95,  val loss 1.132142, percent error 41.70
# Epoch     7, train loss 0.629693, train error 23.95,  val loss 1.130755, percent error 38.20
# Epoch     8, train loss 0.566815, train error 21.32,  val loss 1.205425, percent error 38.90
# Epoch     9, train loss 0.532578, train error 20.68,  val loss 1.188204, percent error 39.10
# Epoch    10, train loss 0.477203, train error 18.00,  val loss 1.189500, percent error 37.70
# Epoch    11, train loss 0.523714, train error 19.57,  val loss 1.340324, percent error 38.10
# Epoch    12, train loss 0.428469, train error 15.82,  val loss 1.330520, percent error 37.40
# Epoch    13, train loss 0.393047, train error 14.60,  val loss 1.344661, percent error 38.00
# Epoch    14, train loss 0.472839, train error 17.78,  val loss 1.451409, percent error 38.70
# Epoch    15, train loss 0.455197, train error 16.35,  val loss 1.566350, percent error 38.80
# Epoch    16, train loss 0.417699, train error 14.38,  val loss 1.548683, percent error 36.60
# Epoch    17, train loss 0.427609, train error 14.70,  val loss 1.549332, percent error 36.50
# Epoch    18, train loss 0.302961, train error 10.85,  val loss 1.505171, percent error 35.00
# Epoch    19, train loss 0.218594, train error 7.95,  val loss 1.404415, percent error 33.00
# Epoch    20, train loss 0.064570, train error 1.28,  val loss 1.237964, percent error 29.60
# Epoch    21, train loss 0.034572, train error 0.18,  val loss 1.263011, percent error 30.10
# Epoch    22, train loss 0.020625, train error 0.00,  val loss 1.286331, percent error 29.50
# Epoch    23, train loss 0.015504, train error 0.03,  val loss 1.318417, percent error 29.90
# Epoch    24, train loss 0.012553, train error 0.00,  val loss 1.347398, percent error 29.30
# Epoch    25, train loss 0.010506, train error 0.00,  val loss 1.384892, percent error 29.80
# Epoch    26, train loss 0.009138, train error 0.00,  val loss 1.407038, percent error 29.30
# Epoch    27, train loss 0.008148, train error 0.00,  val loss 1.432569, percent error 29.60
# Epoch    28, train loss 0.007333, train error 0.00,  val loss 1.452876, percent error 29.80
# Epoch    29, train loss 0.006619, train error 0.00,  val loss 1.470275, percent error 29.50
# Epoch    30, train loss 0.006040, train error 0.00,  val loss 1.487369, percent error 29.40
# Epoch    31, train loss 0.005584, train error 0.00,  val loss 1.507523, percent error 29.80
# Epoch    32, train loss 0.005161, train error 0.00,  val loss 1.519411, percent error 29.40
# Epoch    33, train loss 0.004839, train error 0.00,  val loss 1.537222, percent error 29.50
# Epoch    34, train loss 0.004506, train error 0.00,  val loss 1.550275, percent error 29.40
# Epoch    35, train loss 0.004234, train error 0.00,  val loss 1.563397, percent error 29.50
# Epoch    36, train loss 0.003984, train error 0.00,  val loss 1.576847, percent error 29.60
# Epoch    37, train loss 0.003766, train error 0.00,  val loss 1.587242, percent error 29.40
# Epoch    38, train loss 0.003566, train error 0.00,  val loss 1.599568, percent error 29.60
# Epoch    39, train loss 0.003389, train error 0.00,  val loss 1.610983, percent error 29.70
# Epoch    40, train loss 0.003303, train error 0.00,  val loss 1.615356, percent error 29.60
# Epoch    41, train loss 0.003224, train error 0.00,  val loss 1.620263, percent error 29.60
# Epoch    42, train loss 0.003151, train error 0.00,  val loss 1.625685, percent error 29.70
# Epoch    43, train loss 0.003080, train error 0.00,  val loss 1.630994, percent error 29.60
# Epoch    44, train loss 0.003012, train error 0.00,  val loss 1.635599, percent error 29.80
# Epoch    45, train loss 0.002947, train error 0.00,  val loss 1.640201, percent error 29.70
# Epoch    46, train loss 0.002885, train error 0.00,  val loss 1.645302, percent error 29.60
# Epoch    47, train loss 0.002825, train error 0.00,  val loss 1.649984, percent error 29.70
# Epoch    48, train loss 0.002768, train error 0.00,  val loss 1.653587, percent error 29.60
# Epoch    49, train loss 0.002712, train error 0.00,  val loss 1.658627, percent error 29.70
# Epoch    50, train loss 0.002660, train error 0.00,  val loss 1.662426, percent error 29.70
# Epoch    51, train loss 0.002607, train error 0.00,  val loss 1.667474, percent error 29.80
# Epoch    52, train loss 0.002557, train error 0.00,  val loss 1.670179, percent error 29.80
# Epoch    53, train loss 0.002509, train error 0.00,  val loss 1.675615, percent error 29.80
# Epoch    54, train loss 0.002464, train error 0.00,  val loss 1.679320, percent error 29.70
# Epoch    55, train loss 0.002418, train error 0.00,  val loss 1.683191, percent error 29.80
# Epoch    56, train loss 0.002375, train error 0.00,  val loss 1.687103, percent error 29.80
# Epoch    57, train loss 0.002334, train error 0.00,  val loss 1.691316, percent error 29.90
# Epoch    58, train loss 0.002293, train error 0.00,  val loss 1.694715, percent error 29.90
# Epoch    59, train loss 0.002255, train error 0.00,  val loss 1.698641, percent error 29.90
# Epoch    60, train loss 0.002235, train error 0.00,  val loss 1.700351, percent error 29.90
# Epoch    61, train loss 0.002216, train error 0.00,  val loss 1.702022, percent error 29.90
# Epoch    62, train loss 0.002197, train error 0.00,  val loss 1.703865, percent error 30.10
# Epoch    63, train loss 0.002179, train error 0.00,  val loss 1.705701, percent error 29.90
# Epoch    64, train loss 0.002161, train error 0.00,  val loss 1.707239, percent error 30.00
# Epoch    65, train loss 0.002143, train error 0.00,  val loss 1.709065, percent error 30.10
# Epoch    66, train loss 0.002126, train error 0.00,  val loss 1.710753, percent error 30.10
# Epoch    67, train loss 0.002109, train error 0.00,  val loss 1.712380, percent error 29.90
# Epoch    68, train loss 0.002093, train error 0.00,  val loss 1.714187, percent error 30.00
# Epoch    69, train loss 0.002076, train error 0.00,  val loss 1.716176, percent error 30.00
# Epoch    70, train loss 0.002060, train error 0.00,  val loss 1.717783, percent error 29.90
# Epoch    71, train loss 0.002044, train error 0.00,  val loss 1.719139, percent error 29.90
# Epoch    72, train loss 0.002028, train error 0.00,  val loss 1.720747, percent error 30.00
# Epoch    73, train loss 0.002013, train error 0.00,  val loss 1.722757, percent error 29.90
# Epoch    74, train loss 0.001997, train error 0.00,  val loss 1.723853, percent error 29.90
# Epoch    75, train loss 0.001982, train error 0.00,  val loss 1.725712, percent error 30.00
# Epoch    76, train loss 0.001967, train error 0.00,  val loss 1.727669, percent error 29.90
# Epoch    77, train loss 0.001952, train error 0.00,  val loss 1.728963, percent error 29.90
# Epoch    78, train loss 0.001938, train error 0.00,  val loss 1.730680, percent error 30.10
# Epoch    79, train loss 0.001923, train error 0.00,  val loss 1.732347, percent error 30.00
# Epoch    80, train loss 0.001916, train error 0.00,  val loss 1.733180, percent error 30.10
# Epoch    81, train loss 0.001909, train error 0.00,  val loss 1.734046, percent error 30.00
# Epoch    82, train loss 0.001902, train error 0.00,  val loss 1.734693, percent error 30.00
# Epoch    83, train loss 0.001895, train error 0.00,  val loss 1.735397, percent error 30.00
# Epoch    84, train loss 0.001888, train error 0.00,  val loss 1.736437, percent error 29.90
# Epoch    85, train loss 0.001882, train error 0.00,  val loss 1.737107, percent error 30.00
# Epoch    86, train loss 0.001875, train error 0.00,  val loss 1.737849, percent error 29.90
# Epoch    87, train loss 0.001868, train error 0.00,  val loss 1.738505, percent error 30.00
# Epoch    88, train loss 0.001861, train error 0.00,  val loss 1.739499, percent error 30.00
# Epoch    89, train loss 0.001855, train error 0.00,  val loss 1.740005, percent error 29.90
# Epoch    90, train loss 0.001848, train error 0.00,  val loss 1.740874, percent error 30.00
# Epoch    91, train loss 0.001842, train error 0.00,  val loss 1.741674, percent error 30.00
# Epoch    92, train loss 0.001835, train error 0.00,  val loss 1.742413, percent error 29.90
# Epoch    93, train loss 0.001829, train error 0.00,  val loss 1.743193, percent error 30.00
# Epoch    94, train loss 0.001822, train error 0.00,  val loss 1.743786, percent error 30.00
# Epoch    95, train loss 0.001816, train error 0.00,  val loss 1.744607, percent error 30.00
# Epoch    96, train loss 0.001809, train error 0.00,  val loss 1.745270, percent error 30.00
# Epoch    97, train loss 0.001803, train error 0.00,  val loss 1.746100, percent error 30.00
# Epoch    98, train loss 0.001797, train error 0.00,  val loss 1.746800, percent error 30.00
# Epoch    99, train loss 0.001791, train error 0.00,  val loss 1.747602, percent error 30.00

# %%
# Plot the results
fig, ax = plt.subplots()
ax.plot(errors_train,'r-',label='train')
ax.plot(errors_val,'b-',label='test')
ax.set_ylim(0,100); ax.set_xlim(0,n_epoch)
ax.set_xlabel('Epoch'); ax.set_ylabel('Error')
ax.set_title('TrainError %3.2f, Val Error %3.2f'%(errors_train[-1],errors_val[-1]))
ax.legend()
plt.show()

# %% [markdown]
# The primary motivation of residual networks is to allow training of much deeper networks.
#
# TODO: Try running this network with and without the residual connections.  Does adding the residual connections change the performance?

# %% [markdown]
# Test error from 32.80 (without residual connections) -> 30.00 (with residual connections)
