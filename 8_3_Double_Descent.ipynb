# %% [markdown]
# # **Notebook 8.3: Double Descent**
#
# This notebook investigates double descent as described in section 8.4 of the book.
#
# It uses the MNIST-1D database which can be found at https://github.com/greydanus/mnist1d
#
# Work through the cells below, running each cell in turn. In various places you will see the words "TODO". Follow the instructions at these places and make predictions about what is going to happen or write code to complete the functions.
#
# Contact me at udlbookmail@gmail.com if you find any mistakes or have any suggestions.

# %%
# Run this if you're in a Colab to install MNIST 1D repository
# !pip install git+https://github.com/greydanus/mnist1d
# Out:
# Collecting git+https://github.com/greydanus/mnist1d
#   Cloning https://github.com/greydanus/mnist1d to /tmp/pip-req-build-aofvli4a
#   Running command git clone --filter=blob:none --quiet https://github.com/greydanus/mnist1d /tmp/pip-req-build-aofvli4a
#   Resolved https://github.com/greydanus/mnist1d to commit 7878d96082abd200c546a07a4101fa90b30fdf7e
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# Requirement already satisfied: requests in /usr/local/lib/python3.12/dist-packages (from mnist1d==0.0.2.post16) (2.32.4)
# Requirement already satisfied: numpy in /usr/local/lib/python3.12/dist-packages (from mnist1d==0.0.2.post16) (2.0.2)
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.12/dist-packages (from mnist1d==0.0.2.post16) (3.10.0)
# Requirement already satisfied: scipy in /usr/local/lib/python3.12/dist-packages (from mnist1d==0.0.2.post16) (1.16.3)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib->mnist1d==0.0.2.post16) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.12/dist-packages (from matplotlib->mnist1d==0.0.2.post16) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.12/dist-packages (from matplotlib->mnist1d==0.0.2.post16) (4.63.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib->mnist1d==0.0.2.post16) (1.5.0)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.12/dist-packages (from matplotlib->mnist1d==0.0.2.post16) (26.2)
# Requirement already satisfied: pillow>=8 in /usr/local/lib/python3.12/dist-packages (from matplotlib->mnist1d==0.0.2.post16) (11.3.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib->mnist1d==0.0.2.post16) (3.3.2)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.12/dist-packages (from matplotlib->mnist1d==0.0.2.post16) (2.9.0.post0)
# Requirement already satisfied: charset_normalizer<4,>=2 in /usr/local/lib/python3.12/dist-packages (from requests->mnist1d==0.0.2.post16) (3.4.9)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.12/dist-packages (from requests->mnist1d==0.0.2.post16) (3.18)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.12/dist-packages (from requests->mnist1d==0.0.2.post16) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.12/dist-packages (from requests->mnist1d==0.0.2.post16) (2026.6.17)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.12/dist-packages (from python-dateutil>=2.7->matplotlib->mnist1d==0.0.2.post16) (1.17.0)
# Building wheels for collected packages: mnist1d
#   Building wheel for mnist1d (pyproject.toml) ... done
#   Created wheel for mnist1d: filename=mnist1d-0.0.2.post16-py3-none-any.whl size=15951 sha256=ce3a38e277734fb387ae076f2b1e698e7af37648242d86bdf8221c21c6087e70
#   Stored in directory: /tmp/pip-ephem-wheel-cache-k6v5gz0h/wheels/18/40/b6/29381fee9b4c80fdbc304d52bb065a7286bbcca5ca2b8737c0
# Successfully built mnist1d
# Installing collected packages: mnist1d
# Successfully installed mnist1d-0.0.2.post16

# %%
import torch, torch.nn as nn
from torch.utils.data import TensorDataset, DataLoader
from torch.optim.lr_scheduler import StepLR
import numpy as np
import matplotlib.pyplot as plt
import mnist1d
import random
random.seed(0)

# Try attaching to GPU -- Use "Change Runtime Type to change to GPUT"
DEVICE = str(torch.device('cuda' if torch.cuda.is_available() else 'cpu'))
print('Using:', DEVICE)
# Out:
# Using: cuda

# %%
args = mnist1d.data.get_dataset_args()
args.num_samples = 8000
args.train_split = 0.5
args.corr_noise_scale = 0.25
args.iid_noise_scale=2e-2
data = mnist1d.data.get_dataset(args, path='./mnist1d_data.pkl', download=False, regenerate=True)

# Add 15% noise to training labels
for c_y in range(len(data['y'])):
    random_number = random.random()
    if random_number < 0.15 :
        random_int = int(random.random() * 10)
        data['y'][c_y] = random_int

# The training and test input and outputs are in
# data['x'], data['y'], data['x_test'], and data['y_test']
print("Examples in training set: {}".format(len(data['y'])))
print("Examples in test set: {}".format(len(data['y_test'])))
print("Dimensionality of each example: {}".format(data['x'].shape[-1]))
# Out:
# Did or could not load data from ./mnist1d_data.pkl. Rebuilding dataset...
# Examples in training set: 4000
# Examples in test set: 4000
# Dimensionality of each example: 40

# %%
# Initialize the parameters with He initialization
def weights_init(layer_in):
  if isinstance(layer_in, nn.Linear):
    nn.init.kaiming_uniform_(layer_in.weight)
    layer_in.bias.data.fill_(0.0)

# Return an initialized model with two hidden layers and n_hidden hidden units at each
def get_model(n_hidden):

  D_i = 40    # Input dimensions
  D_k = n_hidden   # Hidden dimensions
  D_o = 10    # Output dimensions

  # Define a model with two hidden layers
  # And ReLU activations between them
  model = nn.Sequential(
  nn.Linear(D_i, D_k),
  nn.ReLU(),
  nn.Linear(D_k, D_k),
  nn.ReLU(),
  nn.Linear(D_k, D_o))

  # Call the function you just defined
  model.apply(weights_init)

  # Return the model
  return model ;

# %%
def fit_model(model, data, n_epoch):

  # choose cross entropy loss function (equation 5.24)
  loss_function = torch.nn.CrossEntropyLoss()
  # construct SGD optimizer and initialize learning rate and momentum
  # optimizer = torch.optim.Adam(model.parameters(), lr=0.01)
  optimizer = torch.optim.SGD(model.parameters(), lr = 0.01, momentum=0.9)


  x_train = torch.tensor(data['x'].astype('float32'))
  y_train = torch.tensor(data['y'].transpose().astype('long'))
  x_test= torch.tensor(data['x_test'].astype('float32'))
  y_test = torch.tensor(data['y_test'].astype('long'))

  # load the data into a class that creates the batches
  data_loader = DataLoader(TensorDataset(x_train,y_train), batch_size=100, shuffle=True, worker_init_fn=np.random.seed(1))

  for epoch in range(n_epoch):
    # loop over batches
    for i, batch in enumerate(data_loader):
      # retrieve inputs and labels for this batch
      x_batch, y_batch = batch
      # zero the parameter gradients
      optimizer.zero_grad()
      # forward pass -- calculate model output
      pred = model(x_batch)
      # compute the loss
      loss = loss_function(pred, y_batch)
      # backward pass
      loss.backward()
      # SGD update
      optimizer.step()

    # Run whole dataset to get statistics -- normally wouldn't do this
    pred_train = model(x_train)
    pred_test = model(x_test)
    _, predicted_train_class = torch.max(pred_train.data, 1)
    _, predicted_test_class = torch.max(pred_test.data, 1)
    errors_train = 100 - 100 * (predicted_train_class == y_train).float().sum() / len(y_train)
    errors_test= 100 - 100 * (predicted_test_class == y_test).float().sum() / len(y_test)
    losses_train = loss_function(pred_train, y_train).item()
    losses_test= loss_function(pred_test, y_test).item()
    if epoch%100 ==0 :
      print(f'Epoch {epoch:5d}, train loss {losses_train:.6f}, train error {errors_train:3.2f},  test loss {losses_test:.6f}, test error {errors_test:3.2f}')

  return errors_train, errors_test

# %%
def count_parameters(model):
    return sum(p.numel() for p in model.parameters() if p.requires_grad)

# %% [markdown]
# The following code produces the double descent curve by training the model with different numbers of hidden units and plotting the test error.
#
# TODO:
#
# *Before* you run the code, and considering that there are 4000 training examples predict:<br>
#
# 1.    At what capacity do you think the training error will become zero?
# 2.   At what capacity do you expect the first minima of the double descent curve to appear?
# 3. At what capacity do you expect the maximum of the double descent curve to appear?

# %%
# This code will take a while (~30 mins on GPU) to run!  Go and make a cup of coffee!

hidden_variables = np.array([2,4,6,8,10,14,18,22,26,30,35,40,45,50,55,60,70,80,90,100,120,140,160,180,200,250,300,400]) ;

errors_train_all = np.zeros_like(hidden_variables)
errors_test_all = np.zeros_like(hidden_variables)
total_weights_all = np.zeros_like(hidden_variables)

# loop over the dataset n_epoch times
n_epoch = 1000

# For each hidden variable size
for c_hidden in range(len(hidden_variables)):
    print(f'Training model with {hidden_variables[c_hidden]:3d} hidden variables')
    # Get a model
    model = get_model(hidden_variables[c_hidden]) ;
    # Count and store number of weights
    total_weights_all[c_hidden] = count_parameters(model)
    # Train the model
    errors_train, errors_test = fit_model(model, data, n_epoch)
    # Store the results
    errors_train_all[c_hidden] = errors_train
    errors_test_all[c_hidden]= errors_test
# Out:
# Training model with   2 hidden variables
# Epoch     0, train loss 2.294781, train error 88.90,  test loss 2.291182, test error 88.57
# Epoch   100, train loss 1.856239, train error 69.80,  test loss 1.700181, test error 68.25
# Epoch   200, train loss 1.856106, train error 70.10,  test loss 1.690988, test error 68.05
# Epoch   300, train loss 1.854002, train error 70.15,  test loss 1.695485, test error 68.05
# Epoch   400, train loss 1.853425, train error 69.95,  test loss 1.697207, test error 68.38
# Epoch   500, train loss 1.853486, train error 70.35,  test loss 1.700767, test error 67.78
# Epoch   600, train loss 1.854581, train error 70.57,  test loss 1.703971, test error 68.22
# Epoch   700, train loss 1.856243, train error 70.25,  test loss 1.711278, test error 68.43
# Epoch   800, train loss 1.851104, train error 70.15,  test loss 1.695435, test error 68.57
# Epoch   900, train loss 1.848750, train error 70.10,  test loss 1.694956, test error 68.50
# Training model with   4 hidden variables
# Epoch     0, train loss 2.296001, train error 87.53,  test loss 2.296361, test error 88.62
# Epoch   100, train loss 1.874680, train error 67.78,  test loss 1.761514, test error 69.70
# Epoch   200, train loss 1.778932, train error 65.68,  test loss 1.609283, test error 63.88
# Epoch   300, train loss 1.763730, train error 64.97,  test loss 1.601730, test error 62.83
# Epoch   400, train loss 1.761922, train error 64.85,  test loss 1.603272, test error 63.20
# Epoch   500, train loss 1.761437, train error 65.43,  test loss 1.606573, test error 63.25
# Epoch   600, train loss 1.757950, train error 65.28,  test loss 1.609750, test error 62.55
# Epoch   700, train loss 1.764115, train error 65.93,  test loss 1.602631, test error 63.60
# Epoch   800, train loss 1.755794, train error 64.40,  test loss 1.595221, test error 62.53
# Epoch   900, train loss 1.757776, train error 64.65,  test loss 1.604609, test error 63.30
# Training model with   6 hidden variables
# Epoch     0, train loss 2.280436, train error 85.12,  test loss 2.270123, test error 84.53
# Epoch   100, train loss 1.699296, train error 61.67,  test loss 1.546848, test error 60.08
# Epoch   200, train loss 1.627530, train error 57.53,  test loss 1.468238, test error 55.22
# Epoch   300, train loss 1.605356, train error 55.72,  test loss 1.448617, test error 53.62
# Epoch   400, train loss 1.588211, train error 55.08,  test loss 1.435216, test error 52.67
# Epoch   500, train loss 1.574930, train error 55.38,  test loss 1.409545, test error 52.47
# Epoch   600, train loss 1.560299, train error 54.88,  test loss 1.392796, test error 51.17
# Epoch   700, train loss 1.561091, train error 55.03,  test loss 1.392344, test error 51.75
# Epoch   800, train loss 1.556512, train error 54.53,  test loss 1.391545, test error 51.15
# Epoch   900, train loss 1.558753, train error 55.12,  test loss 1.397532, test error 52.03
# Training model with   8 hidden variables
# Epoch     0, train loss 2.268132, train error 84.25,  test loss 2.261384, test error 83.70
# Epoch   100, train loss 1.589218, train error 56.40,  test loss 1.473414, test error 57.58
# Epoch   200, train loss 1.556593, train error 55.53,  test loss 1.433954, test error 55.12
# Epoch   300, train loss 1.529980, train error 54.12,  test loss 1.430601, test error 54.55
# Epoch   400, train loss 1.520715, train error 53.28,  test loss 1.419368, test error 54.28
# Epoch   500, train loss 1.523769, train error 54.22,  test loss 1.427180, test error 55.28
# Epoch   600, train loss 1.518200, train error 52.92,  test loss 1.419584, test error 54.42
# Epoch   700, train loss 1.515024, train error 52.80,  test loss 1.434641, test error 54.62
# Epoch   800, train loss 1.512259, train error 53.33,  test loss 1.436989, test error 55.20
# Epoch   900, train loss 1.507530, train error 53.38,  test loss 1.437126, test error 54.35
# Training model with  10 hidden variables
# Epoch     0, train loss 2.149001, train error 80.12,  test loss 2.085693, test error 79.43
# Epoch   100, train loss 1.558810, train error 54.50,  test loss 1.405408, test error 53.05
# Epoch   200, train loss 1.487324, train error 51.92,  test loss 1.384198, test error 52.08
# Epoch   300, train loss 1.462042, train error 51.62,  test loss 1.399926, test error 52.80
# Epoch   400, train loss 1.447913, train error 51.33,  test loss 1.403698, test error 52.65
# Epoch   500, train loss 1.435240, train error 50.70,  test loss 1.399272, test error 52.42
# Epoch   600, train loss 1.431370, train error 49.75,  test loss 1.405110, test error 52.60
# Epoch   700, train loss 1.424963, train error 49.97,  test loss 1.421528, test error 52.90
# Epoch   800, train loss 1.424149, train error 50.40,  test loss 1.424619, test error 52.75
# Epoch   900, train loss 1.425107, train error 50.50,  test loss 1.418459, test error 52.88
# Training model with  14 hidden variables
# Epoch     0, train loss 2.250685, train error 84.07,  test loss 2.234712, test error 83.05
# Epoch   100, train loss 1.422212, train error 48.42,  test loss 1.328759, test error 49.97
# Epoch   200, train loss 1.349570, train error 45.20,  test loss 1.301509, test error 49.30
# Epoch   300, train loss 1.320826, train error 44.88,  test loss 1.322814, test error 49.60
# Epoch   400, train loss 1.309883, train error 44.92,  test loss 1.352153, test error 50.50
# Epoch   500, train loss 1.294724, train error 44.12,  test loss 1.369553, test error 50.60
# Epoch   600, train loss 1.290292, train error 44.62,  test loss 1.389016, test error 51.30
# Epoch   700, train loss 1.279232, train error 44.47,  test loss 1.397581, test error 51.28
# Epoch   800, train loss 1.280138, train error 44.53,  test loss 1.417180, test error 51.85
# Epoch   900, train loss 1.273669, train error 43.80,  test loss 1.420202, test error 52.10
# Training model with  18 hidden variables
# Epoch     0, train loss 2.187029, train error 82.38,  test loss 2.155137, test error 79.90
# Epoch   100, train loss 1.379147, train error 46.38,  test loss 1.357901, test error 51.05
# Epoch   200, train loss 1.284504, train error 43.30,  test loss 1.356420, test error 49.83
# Epoch   300, train loss 1.249607, train error 41.50,  test loss 1.373060, test error 49.90
# Epoch   400, train loss 1.226154, train error 42.12,  test loss 1.413170, test error 50.12
# Epoch   500, train loss 1.207541, train error 41.35,  test loss 1.467180, test error 51.60
# Epoch   600, train loss 1.188869, train error 41.08,  test loss 1.477372, test error 51.35
# Epoch   700, train loss 1.181807, train error 40.25,  test loss 1.504791, test error 51.50
# Epoch   800, train loss 1.170322, train error 39.83,  test loss 1.511422, test error 51.28
# Epoch   900, train loss 1.166148, train error 39.70,  test loss 1.532659, test error 50.12
# Training model with  22 hidden variables
# Epoch     0, train loss 2.224250, train error 81.93,  test loss 2.207037, test error 82.38
# Epoch   100, train loss 1.269149, train error 41.83,  test loss 1.314835, test error 48.60
# Epoch   200, train loss 1.162747, train error 37.33,  test loss 1.370301, test error 49.33
# Epoch   300, train loss 1.102946, train error 35.82,  test loss 1.428649, test error 49.67
# Epoch   400, train loss 1.067901, train error 34.90,  test loss 1.485049, test error 49.55
# Epoch   500, train loss 1.062138, train error 34.82,  test loss 1.559387, test error 51.10
# Epoch   600, train loss 1.040935, train error 34.12,  test loss 1.619387, test error 51.45
# Epoch   700, train loss 1.034096, train error 34.32,  test loss 1.658749, test error 51.50
# Epoch   800, train loss 1.011617, train error 33.82,  test loss 1.703995, test error 51.80
# Epoch   900, train loss 1.002148, train error 33.47,  test loss 1.723118, test error 51.88
# Training model with  26 hidden variables
# Epoch     0, train loss 2.185632, train error 80.97,  test loss 2.157699, test error 80.12
# Epoch   100, train loss 1.180303, train error 39.30,  test loss 1.322453, test error 48.55
# Epoch   200, train loss 1.034669, train error 34.55,  test loss 1.439065, test error 49.95
# Epoch   300, train loss 0.951313, train error 31.00,  test loss 1.538967, test error 51.45
# Epoch   400, train loss 0.931638, train error 31.03,  test loss 1.614006, test error 50.60
# Epoch   500, train loss 0.892214, train error 29.78,  test loss 1.692970, test error 51.45
# Epoch   600, train loss 0.868365, train error 28.72,  test loss 1.750757, test error 51.20
# Epoch   700, train loss 0.862920, train error 29.32,  test loss 1.819750, test error 51.72
# Epoch   800, train loss 0.841250, train error 27.85,  test loss 1.840757, test error 50.83
# Epoch   900, train loss 0.822467, train error 27.10,  test loss 1.917335, test error 52.45
# Training model with  30 hidden variables
# Epoch     0, train loss 2.200801, train error 80.70,  test loss 2.222669, test error 82.43
# Epoch   100, train loss 1.106968, train error 36.03,  test loss 1.371060, test error 49.78
# Epoch   200, train loss 0.911617, train error 29.47,  test loss 1.558217, test error 51.20
# Epoch   300, train loss 0.818292, train error 26.85,  test loss 1.789082, test error 52.33
# Epoch   400, train loss 0.771224, train error 25.35,  test loss 1.997717, test error 53.15
# Epoch   500, train loss 0.728838, train error 24.20,  test loss 2.158604, test error 53.47
# Epoch   600, train loss 0.693807, train error 23.32,  test loss 2.338030, test error 53.58
# Epoch   700, train loss 0.678364, train error 22.80,  test loss 2.541105, test error 55.10
# Epoch   800, train loss 0.653925, train error 21.53,  test loss 2.683857, test error 54.90
# Epoch   900, train loss 0.666973, train error 23.18,  test loss 2.860110, test error 55.72
# Training model with  35 hidden variables
# Epoch     0, train loss 2.164466, train error 80.85,  test loss 2.139469, test error 81.00
# Epoch   100, train loss 1.025974, train error 33.43,  test loss 1.374974, test error 49.12
# Epoch   200, train loss 0.783283, train error 25.05,  test loss 1.670030, test error 51.40
# Epoch   300, train loss 0.663186, train error 21.57,  test loss 2.024908, test error 51.70
# Epoch   400, train loss 0.579090, train error 18.47,  test loss 2.402778, test error 53.92
# Epoch   500, train loss 0.539933, train error 17.90,  test loss 2.773253, test error 53.80
# Epoch   600, train loss 0.532552, train error 18.22,  test loss 3.055484, test error 53.92
# Epoch   700, train loss 0.467143, train error 15.65,  test loss 3.334235, test error 55.15
# Epoch   800, train loss 0.457763, train error 14.88,  test loss 3.661440, test error 54.58
# Epoch   900, train loss 0.450573, train error 15.45,  test loss 3.941897, test error 55.67
# Training model with  40 hidden variables
# Epoch     0, train loss 2.091245, train error 77.95,  test loss 2.049630, test error 77.93
# Epoch   100, train loss 0.908640, train error 29.07,  test loss 1.407552, test error 49.10
# Epoch   200, train loss 0.636500, train error 21.65,  test loss 1.903657, test error 51.28
# Epoch   300, train loss 0.511069, train error 17.90,  test loss 2.576602, test error 54.35
# Epoch   400, train loss 0.415830, train error 14.65,  test loss 3.263991, test error 55.00
# Epoch   500, train loss 0.344398, train error 11.60,  test loss 3.833670, test error 54.97
# Epoch   600, train loss 0.292570, train error 9.80,  test loss 4.567755, test error 55.85
# Epoch   700, train loss 0.318206, train error 11.30,  test loss 5.257442, test error 56.83
# Epoch   800, train loss 0.273324, train error 10.10,  test loss 5.903526, test error 57.65
# Epoch   900, train loss 0.256833, train error 9.30,  test loss 6.392145, test error 57.45
# Training model with  45 hidden variables
# Epoch     0, train loss 2.091710, train error 77.85,  test loss 2.046782, test error 77.93
# Epoch   100, train loss 0.816387, train error 24.75,  test loss 1.453109, test error 49.88
# Epoch   200, train loss 0.511707, train error 15.78,  test loss 2.181692, test error 53.45
# Epoch   300, train loss 0.321595, train error 10.18,  test loss 3.112833, test error 55.62
# Epoch   400, train loss 0.219991, train error 6.45,  test loss 4.301373, test error 56.03
# Epoch   500, train loss 0.166562, train error 5.75,  test loss 5.626651, test error 56.90
# Epoch   600, train loss 0.136757, train error 4.35,  test loss 6.762383, test error 56.10
# Epoch   700, train loss 0.158796, train error 5.32,  test loss 7.827629, test error 56.30
# Epoch   800, train loss 0.110984, train error 3.80,  test loss 8.839800, test error 56.60
# Epoch   900, train loss 0.004422, train error 0.00,  test loss 9.569405, test error 56.75
# Training model with  50 hidden variables
# Epoch     0, train loss 2.076600, train error 77.10,  test loss 1.995989, test error 75.57
# Epoch   100, train loss 0.735851, train error 22.50,  test loss 1.559429, test error 51.20
# Epoch   200, train loss 0.353455, train error 10.20,  test loss 2.527655, test error 53.20
# Epoch   300, train loss 0.153445, train error 3.82,  test loss 4.046510, test error 55.50
# Epoch   400, train loss 0.027951, train error 0.00,  test loss 5.625342, test error 56.15
# Epoch   500, train loss 0.013171, train error 0.00,  test loss 6.570764, test error 55.95
# Epoch   600, train loss 0.007900, train error 0.00,  test loss 7.179298, test error 56.03
# Epoch   700, train loss 0.005648, train error 0.00,  test loss 7.631839, test error 56.03
# Epoch   800, train loss 0.004376, train error 0.00,  test loss 8.001780, test error 56.10
# Epoch   900, train loss 0.003523, train error 0.00,  test loss 8.299538, test error 55.95
# Training model with  55 hidden variables
# Epoch     0, train loss 2.095476, train error 78.25,  test loss 2.068346, test error 77.03
# Epoch   100, train loss 0.609186, train error 18.60,  test loss 1.694506, test error 51.15
# Epoch   200, train loss 0.180358, train error 3.53,  test loss 3.032747, test error 53.03
# Epoch   300, train loss 0.038008, train error 0.03,  test loss 4.648374, test error 53.92
# Epoch   400, train loss 0.013718, train error 0.00,  test loss 5.563601, test error 53.88
# Epoch   500, train loss 0.007981, train error 0.00,  test loss 6.125891, test error 53.92
# Epoch   600, train loss 0.005546, train error 0.00,  test loss 6.546400, test error 54.12
# Epoch   700, train loss 0.004175, train error 0.00,  test loss 6.859462, test error 54.12
# Epoch   800, train loss 0.003320, train error 0.00,  test loss 7.120032, test error 54.05
# Epoch   900, train loss 0.002729, train error 0.00,  test loss 7.346096, test error 54.15
# Training model with  60 hidden variables
# Epoch     0, train loss 2.087924, train error 77.82,  test loss 2.054818, test error 78.25
# Epoch   100, train loss 0.561321, train error 16.82,  test loss 1.842535, test error 53.75
# Epoch   200, train loss 0.123778, train error 1.78,  test loss 3.431702, test error 53.92
# Epoch   300, train loss 0.019917, train error 0.00,  test loss 4.866949, test error 55.12
# Epoch   400, train loss 0.009535, train error 0.00,  test loss 5.601664, test error 55.12
# Epoch   500, train loss 0.006050, train error 0.00,  test loss 6.070206, test error 55.25
# Epoch   600, train loss 0.004316, train error 0.00,  test loss 6.429824, test error 55.17
# Epoch   700, train loss 0.003305, train error 0.00,  test loss 6.706183, test error 55.17
# Epoch   800, train loss 0.002662, train error 0.00,  test loss 6.941633, test error 55.20
# Epoch   900, train loss 0.002208, train error 0.00,  test loss 7.140408, test error 55.03
# Training model with  70 hidden variables
# Epoch     0, train loss 2.039936, train error 75.57,  test loss 1.977349, test error 75.62
# Epoch   100, train loss 0.363052, train error 8.65,  test loss 1.944661, test error 52.17
# Epoch   200, train loss 0.035127, train error 0.00,  test loss 3.611009, test error 54.00
# Epoch   300, train loss 0.011432, train error 0.00,  test loss 4.434348, test error 53.65
# Epoch   400, train loss 0.006334, train error 0.00,  test loss 4.899705, test error 53.97
# Epoch   500, train loss 0.004231, train error 0.00,  test loss 5.214368, test error 54.05
# Epoch   600, train loss 0.003132, train error 0.00,  test loss 5.455369, test error 54.10
# Epoch   700, train loss 0.002452, train error 0.00,  test loss 5.649209, test error 54.17
# Epoch   800, train loss 0.002000, train error 0.00,  test loss 5.810787, test error 54.10
# Epoch   900, train loss 0.001682, train error 0.00,  test loss 5.949537, test error 54.12
# Training model with  80 hidden variables
# Epoch     0, train loss 2.039082, train error 75.47,  test loss 1.954040, test error 74.25
# Epoch   100, train loss 0.230621, train error 3.97,  test loss 2.165991, test error 52.95
# Epoch   200, train loss 0.019717, train error 0.00,  test loss 3.546508, test error 53.97
# Epoch   300, train loss 0.008042, train error 0.00,  test loss 4.134998, test error 54.42
# Epoch   400, train loss 0.004750, train error 0.00,  test loss 4.479361, test error 54.22
# Epoch   500, train loss 0.003286, train error 0.00,  test loss 4.723036, test error 54.30
# Epoch   600, train loss 0.002477, train error 0.00,  test loss 4.915583, test error 54.12
# Epoch   700, train loss 0.001965, train error 0.00,  test loss 5.069489, test error 54.10
# Epoch   800, train loss 0.001618, train error 0.00,  test loss 5.200387, test error 54.25
# Epoch   900, train loss 0.001368, train error 0.00,  test loss 5.311426, test error 54.35
# Training model with  90 hidden variables
# Epoch     0, train loss 2.020227, train error 73.72,  test loss 1.953424, test error 73.95
# Epoch   100, train loss 0.159087, train error 1.72,  test loss 2.160888, test error 50.88
# Epoch   200, train loss 0.015368, train error 0.00,  test loss 3.228016, test error 51.65
# Epoch   300, train loss 0.006665, train error 0.00,  test loss 3.651412, test error 51.58
# Epoch   400, train loss 0.004046, train error 0.00,  test loss 3.920543, test error 51.65
# Epoch   500, train loss 0.002837, train error 0.00,  test loss 4.111683, test error 51.70
# Epoch   600, train loss 0.002153, train error 0.00,  test loss 4.260516, test error 51.78
# Epoch   700, train loss 0.001719, train error 0.00,  test loss 4.383693, test error 51.67
# Epoch   800, train loss 0.001421, train error 0.00,  test loss 4.486909, test error 51.65
# Epoch   900, train loss 0.001205, train error 0.00,  test loss 4.577384, test error 51.78
# Training model with 100 hidden variables
# Epoch     0, train loss 1.989588, train error 74.22,  test loss 1.913306, test error 75.00
# Epoch   100, train loss 0.085170, train error 0.15,  test loss 2.255661, test error 51.42
# Epoch   200, train loss 0.011865, train error 0.00,  test loss 3.089439, test error 51.97
# Epoch   300, train loss 0.005542, train error 0.00,  test loss 3.443477, test error 52.17
# Epoch   400, train loss 0.003467, train error 0.00,  test loss 3.663208, test error 52.15
# Epoch   500, train loss 0.002471, train error 0.00,  test loss 3.823206, test error 52.00
# Epoch   600, train loss 0.001893, train error 0.00,  test loss 3.951073, test error 52.05
# Epoch   700, train loss 0.001523, train error 0.00,  test loss 4.054009, test error 51.97
# Epoch   800, train loss 0.001266, train error 0.00,  test loss 4.142772, test error 52.03
# Epoch   900, train loss 0.001078, train error 0.00,  test loss 4.220194, test error 51.95
# Training model with 120 hidden variables
# Epoch     0, train loss 1.990149, train error 74.10,  test loss 1.950279, test error 74.40
# Epoch   100, train loss 0.054305, train error 0.00,  test loss 2.192004, test error 49.67
# Epoch   200, train loss 0.009859, train error 0.00,  test loss 2.822551, test error 50.33
# Epoch   300, train loss 0.004829, train error 0.00,  test loss 3.101670, test error 50.28
# Epoch   400, train loss 0.003067, train error 0.00,  test loss 3.282252, test error 50.22
# Epoch   500, train loss 0.002207, train error 0.00,  test loss 3.414799, test error 50.20
# Epoch   600, train loss 0.001703, train error 0.00,  test loss 3.520622, test error 50.25
# Epoch   700, train loss 0.001375, train error 0.00,  test loss 3.607748, test error 50.35
# Epoch   800, train loss 0.001147, train error 0.00,  test loss 3.681172, test error 50.35
# Epoch   900, train loss 0.000979, train error 0.00,  test loss 3.745409, test error 50.40
# Training model with 140 hidden variables
# Epoch     0, train loss 1.935027, train error 70.72,  test loss 1.880276, test error 71.75
# Epoch   100, train loss 0.037546, train error 0.00,  test loss 2.123940, test error 49.38
# Epoch   200, train loss 0.008229, train error 0.00,  test loss 2.595992, test error 49.65
# Epoch   300, train loss 0.004225, train error 0.00,  test loss 2.816110, test error 49.78
# Epoch   400, train loss 0.002738, train error 0.00,  test loss 2.964170, test error 50.05
# Epoch   500, train loss 0.001992, train error 0.00,  test loss 3.071973, test error 49.95
# Epoch   600, train loss 0.001549, train error 0.00,  test loss 3.159651, test error 49.90
# Epoch   700, train loss 0.001258, train error 0.00,  test loss 3.231329, test error 49.83
# Epoch   800, train loss 0.001054, train error 0.00,  test loss 3.292373, test error 49.92
# Epoch   900, train loss 0.000903, train error 0.00,  test loss 3.346123, test error 50.08
# Training model with 160 hidden variables
# Epoch     0, train loss 1.957675, train error 71.62,  test loss 1.871067, test error 72.28
# Epoch   100, train loss 0.029697, train error 0.00,  test loss 2.193299, test error 49.17
# Epoch   200, train loss 0.007244, train error 0.00,  test loss 2.647275, test error 49.42
# Epoch   300, train loss 0.003797, train error 0.00,  test loss 2.865859, test error 49.65
# Epoch   400, train loss 0.002491, train error 0.00,  test loss 3.007802, test error 49.58
# Epoch   500, train loss 0.001820, train error 0.00,  test loss 3.115707, test error 49.75
# Epoch   600, train loss 0.001420, train error 0.00,  test loss 3.201953, test error 49.67
# Epoch   700, train loss 0.001156, train error 0.00,  test loss 3.273459, test error 49.67
# Epoch   800, train loss 0.000970, train error 0.00,  test loss 3.335062, test error 49.67
# Epoch   900, train loss 0.000833, train error 0.00,  test loss 3.387967, test error 49.58
# Training model with 180 hidden variables
# Epoch     0, train loss 1.917190, train error 70.32,  test loss 1.840990, test error 72.38
# Epoch   100, train loss 0.024957, train error 0.00,  test loss 2.028346, test error 48.65
# Epoch   200, train loss 0.006582, train error 0.00,  test loss 2.389204, test error 48.38
# Epoch   300, train loss 0.003500, train error 0.00,  test loss 2.570526, test error 48.45
# Epoch   400, train loss 0.002314, train error 0.00,  test loss 2.688403, test error 48.47
# Epoch   500, train loss 0.001701, train error 0.00,  test loss 2.778326, test error 48.47
# Epoch   600, train loss 0.001331, train error 0.00,  test loss 2.850186, test error 48.53
# Epoch   700, train loss 0.001086, train error 0.00,  test loss 2.909719, test error 48.47
# Epoch   800, train loss 0.000912, train error 0.00,  test loss 2.961258, test error 48.45
# Epoch   900, train loss 0.000784, train error 0.00,  test loss 3.006801, test error 48.42
# Training model with 200 hidden variables
# Epoch     0, train loss 1.920625, train error 70.00,  test loss 1.846840, test error 71.15
# Epoch   100, train loss 0.021516, train error 0.00,  test loss 1.980616, test error 48.35
# Epoch   200, train loss 0.006098, train error 0.00,  test loss 2.292376, test error 48.10
# Epoch   300, train loss 0.003306, train error 0.00,  test loss 2.451939, test error 48.15
# Epoch   400, train loss 0.002201, train error 0.00,  test loss 2.559324, test error 48.17
# Epoch   500, train loss 0.001625, train error 0.00,  test loss 2.640634, test error 48.12
# Epoch   600, train loss 0.001276, train error 0.00,  test loss 2.705848, test error 48.12
# Epoch   700, train loss 0.001044, train error 0.00,  test loss 2.759994, test error 48.03
# Epoch   800, train loss 0.000879, train error 0.00,  test loss 2.806515, test error 48.05
# Epoch   900, train loss 0.000757, train error 0.00,  test loss 2.847894, test error 47.92
# Training model with 250 hidden variables
# Epoch     0, train loss 1.873486, train error 68.07,  test loss 1.819652, test error 71.10
# Epoch   100, train loss 0.016935, train error 0.00,  test loss 1.936688, test error 46.88
# Epoch   200, train loss 0.005299, train error 0.00,  test loss 2.190295, test error 47.00
# Epoch   300, train loss 0.002957, train error 0.00,  test loss 2.326566, test error 46.97
# Epoch   400, train loss 0.001997, train error 0.00,  test loss 2.417257, test error 46.88
# Epoch   500, train loss 0.001487, train error 0.00,  test loss 2.487445, test error 46.90
# Epoch   600, train loss 0.001174, train error 0.00,  test loss 2.544288, test error 46.88
# Epoch   700, train loss 0.000964, train error 0.00,  test loss 2.591692, test error 46.83
# Epoch   800, train loss 0.000814, train error 0.00,  test loss 2.631705, test error 46.83
# Epoch   900, train loss 0.000702, train error 0.00,  test loss 2.667154, test error 46.85
# Training model with 300 hidden variables
# Epoch     0, train loss 1.877121, train error 68.07,  test loss 1.815054, test error 71.07
# Epoch   100, train loss 0.014513, train error 0.00,  test loss 1.847959, test error 45.50
# Epoch   200, train loss 0.004819, train error 0.00,  test loss 2.065967, test error 45.15
# Epoch   300, train loss 0.002730, train error 0.00,  test loss 2.184122, test error 45.00
# Epoch   400, train loss 0.001858, train error 0.00,  test loss 2.266508, test error 45.08
# Epoch   500, train loss 0.001391, train error 0.00,  test loss 2.329393, test error 44.92
# Epoch   600, train loss 0.001102, train error 0.00,  test loss 2.380441, test error 45.03
# Epoch   700, train loss 0.000907, train error 0.00,  test loss 2.422591, test error 45.08
# Epoch   800, train loss 0.000768, train error 0.00,  test loss 2.459424, test error 45.08
# Epoch   900, train loss 0.000663, train error 0.00,  test loss 2.491222, test error 45.00
# Training model with 400 hidden variables
# Epoch     0, train loss 1.822763, train error 65.62,  test loss 1.778142, test error 69.07
# Epoch   100, train loss 0.011510, train error 0.00,  test loss 1.768910, test error 46.35
# Epoch   200, train loss 0.004142, train error 0.00,  test loss 1.941991, test error 45.83
# Epoch   300, train loss 0.002398, train error 0.00,  test loss 2.039858, test error 45.95
# Epoch   400, train loss 0.001653, train error 0.00,  test loss 2.107347, test error 45.85
# Epoch   500, train loss 0.001246, train error 0.00,  test loss 2.160004, test error 45.90
# Epoch   600, train loss 0.000993, train error 0.00,  test loss 2.202504, test error 45.75
# Epoch   700, train loss 0.000821, train error 0.00,  test loss 2.237891, test error 45.90
# Epoch   800, train loss 0.000697, train error 0.00,  test loss 2.268852, test error 45.88
# Epoch   900, train loss 0.000603, train error 0.00,  test loss 2.296265, test error 45.75

# %%
import matplotlib.pyplot as plt
import numpy as np

# Assuming data['y'] is available and contains the training examples
num_training_examples = len(data['y'])

# Find the index where total_weights_all is closest to num_training_examples
closest_index = np.argmin(np.abs(np.array(total_weights_all) - num_training_examples))

# Get the corresponding value of hidden variables
hidden_variable_at_num_training_examples = hidden_variables[closest_index]

# Plot the results
fig, ax = plt.subplots()
ax.plot(hidden_variables, errors_train_all, 'r-', label='train')
ax.plot(hidden_variables, errors_test_all, 'b-', label='test')

# Add a vertical line at the point where total weights equal the number of training examples
ax.axvline(x=hidden_variable_at_num_training_examples, color='g', linestyle='--', label='N(weights) = N(train)')

ax.set_ylim(0, 100)
ax.set_xlabel('No. hidden variables')
ax.set_ylabel('Error')
ax.legend()
plt.show()
