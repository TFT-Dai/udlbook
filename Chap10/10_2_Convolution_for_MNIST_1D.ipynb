# %% [markdown]
# # **Notebook 10.2: Convolution for MNIST-1D**
#
# This notebook investigates a 1D convolutional network for MNIST-1D as in figure 10.7 and 10.8a.
#
# Work through the cells below, running each cell in turn. In various places you will see the words "TODO". Follow the instructions at these places and make predictions about what is going to happen or write code to complete the functions.
#
# Contact me at udlbookmail@gmail.com if you find any mistakes or have any suggestions.

# %%
# Run this if you're in a Colab to install MNIST 1D repository
# !pip install git+https://github.com/greydanus/mnist1d
# Out:
# Collecting git+https://github.com/greydanus/mnist1d
#   Cloning https://github.com/greydanus/mnist1d to /tmp/pip-req-build-761cbza3
#   Running command git clone --filter=blob:none --quiet https://github.com/greydanus/mnist1d /tmp/pip-req-build-761cbza3
#   Resolved https://github.com/greydanus/mnist1d to commit 7878d96082abd200c546a07a4101fa90b30fdf7e
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# Requirement already satisfied: requests in /usr/local/lib/python3.12/dist-packages (from mnist1d==0.0.2.post16) (2.32.4)
# Requirement already satisfied: numpy in /usr/local/lib/python3.12/dist-packages (from mnist1d==0.0.2.post16) (2.0.2)
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.12/dist-packages (from mnist1d==0.0.2.post16) (3.10.0)
# Requirement already satisfied: scipy in /usr/local/lib/python3.12/dist-packages (from mnist1d==0.0.2.post16) (1.16.3)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib->mnist1d==0.0.2.post16) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.12/dist-packages (from matplotlib->mnist1d==0.0.2.post16) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.12/dist-packages (from matplotlib->mnist1d==0.0.2.post16) (4.63.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib->mnist1d==0.0.2.post16) (1.5.0)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.12/dist-packages (from matplotlib->mnist1d==0.0.2.post16) (26.2)
# Requirement already satisfied: pillow>=8 in /usr/local/lib/python3.12/dist-packages (from matplotlib->mnist1d==0.0.2.post16) (11.3.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib->mnist1d==0.0.2.post16) (3.3.2)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.12/dist-packages (from matplotlib->mnist1d==0.0.2.post16) (2.9.0.post0)
# Requirement already satisfied: charset_normalizer<4,>=2 in /usr/local/lib/python3.12/dist-packages (from requests->mnist1d==0.0.2.post16) (3.4.9)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.12/dist-packages (from requests->mnist1d==0.0.2.post16) (3.18)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.12/dist-packages (from requests->mnist1d==0.0.2.post16) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.12/dist-packages (from requests->mnist1d==0.0.2.post16) (2026.6.17)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.12/dist-packages (from python-dateutil>=2.7->matplotlib->mnist1d==0.0.2.post16) (1.17.0)
# Building wheels for collected packages: mnist1d
#   Building wheel for mnist1d (pyproject.toml) ... done
#   Created wheel for mnist1d: filename=mnist1d-0.0.2.post16-py3-none-any.whl size=14665 sha256=00863ef22545ec05026e734b9084a912f8a72f52650a3d45677320f0539bc4b0
#   Stored in directory: /tmp/pip-ephem-wheel-cache-ggxi_tsp/wheels/18/40/b6/29381fee9b4c80fdbc304d52bb065a7286bbcca5ca2b8737c0
# Successfully built mnist1d
# Installing collected packages: mnist1d
# Successfully installed mnist1d-0.0.2.post16

# %%
import numpy as np
import os
import torch, torch.nn as nn
from torch.utils.data import TensorDataset, DataLoader
from torch.optim.lr_scheduler import StepLR
import matplotlib.pyplot as plt
import mnist1d
import random

# %%
args = mnist1d.data.get_dataset_args()
data = mnist1d.data.get_dataset(args, path='./mnist1d_data.pkl', download=False, regenerate=False)

# The training and test input and outputs are in
# data['x'], data['y'], data['x_test'], and data['y_test']
print("Examples in training set: {}".format(len(data['y'])))
print("Examples in test set: {}".format(len(data['y_test'])))
print("Length of each example: {}".format(data['x'].shape[-1]))
# Out:
# Did or could not load data from ./mnist1d_data.pkl. Rebuilding dataset...
# Examples in training set: 4000
# Examples in test set: 1000
# Length of each example: 40

# %%
# Load in the data
train_data_x = data['x'].transpose()
train_data_y = data['y']
val_data_x = data['x_test'].transpose()
val_data_y = data['y_test']
# Print out sizes
print("Train data: %d examples (columns), each of which has %d dimensions (rows)"%((train_data_x.shape[1],train_data_x.shape[0])))
print("Validation data: %d examples (columns), each of which has %d dimensions (rows)"%((val_data_x.shape[1],val_data_x.shape[0])))
# Out:
# Train data: 4000 examples (columns), each of which has 40 dimensions (rows)
# Validation data: 1000 examples (columns), each of which has 40 dimensions (rows)

# %% [markdown]
# Define the network

# %%
# There are 40 input dimensions and 10 output dimensions for this data
# The inputs correspond to the 40 offsets in the MNIST1D template.
D_i = 40
# The outputs correspond to the 10 digits
D_o = 10


# TODO Create a model with the following layers
# 1. Convolutional layer, (input=length 40 and 1 channel, kernel size 3, stride 2, padding="valid", 15 output channels )
# 2. ReLU
# 3. Convolutional layer, (input=length 19 and 15 channels, kernel size 3, stride 2, padding="valid", 15 output channels )
# 4. ReLU
# 5. Convolutional layer, (input=length 9 and 15 channels, kernel size 3, stride 2, padding="valid", 15 output channels)
# 6. ReLU
# 7. Flatten (converts 4x15) to length 60
# 8. Linear layer (input size = 60, output size = 10)
# References:
# https://pytorch.org/docs/1.13/generated/torch.nn.Conv1d.html?highlight=conv1d#torch.nn.Conv1d
# https://pytorch.org/docs/stable/generated/torch.nn.Flatten.html
# https://pytorch.org/docs/1.13/generated/torch.nn.Linear.html?highlight=linear#torch.nn.Linear

# NOTE THAT THE CONVOLUTIONAL LAYERS NEED TO TAKE THE NUMBER OF INPUT CHANNELS AS A PARAMETER
# AND NOT THE INPUT SIZE.

# Replace the following function:
model = nn.Sequential(
    nn.Conv1d(1,  15, kernel_size=3, stride=2, padding=0),  # 40 -> 19
    nn.ReLU(),
    nn.Conv1d(15, 15, kernel_size=3, stride=2, padding=0),  # 19 ->  9
    nn.ReLU(),
    nn.Conv1d(15, 15, kernel_size=3, stride=2, padding=0),  #  9 ->  4
    nn.ReLU(),
    nn.Flatten(),                                           # 15*4 = 60
    nn.Linear(60, D_o)                                      # 60 -> 10
)

# %%
# He initialization of weights
def weights_init(layer_in):
  if isinstance(layer_in, nn.Linear):
    nn.init.kaiming_uniform_(layer_in.weight)
    layer_in.bias.data.fill_(0.0)

# %%
# choose cross entropy loss function (equation 5.24 in the loss notes)
loss_function = nn.CrossEntropyLoss()
# construct SGD optimizer and initialize learning rate and momentum
optimizer = torch.optim.SGD(model.parameters(), lr = 0.05, momentum=0.9)
# object that decreases learning rate by half every 20 epochs
scheduler = StepLR(optimizer, step_size=20, gamma=0.5)
# create 100 dummy data points and store in data loader class
x_train = torch.tensor(train_data_x.transpose().astype('float32'))
y_train = torch.tensor(train_data_y.astype('long')).long()
x_val= torch.tensor(val_data_x.transpose().astype('float32'))
y_val = torch.tensor(val_data_y.astype('long')).long()

# load the data into a class that creates the batches
data_loader = DataLoader(TensorDataset(x_train,y_train), batch_size=100, shuffle=True, worker_init_fn=np.random.seed(1))

# Initialize model weights
model.apply(weights_init)

# loop over the dataset n_epoch times
n_epoch = 100
# store the loss and the % correct at each epoch
losses_train = np.zeros((n_epoch))
errors_train = np.zeros((n_epoch))
losses_val = np.zeros((n_epoch))
errors_val = np.zeros((n_epoch))

for epoch in range(n_epoch):
  # loop over batches
  for i, data in enumerate(data_loader):
    # retrieve inputs and labels for this batch
    x_batch, y_batch = data
    # zero the parameter gradients
    optimizer.zero_grad()
    # forward pass -- calculate model output
    pred = model(x_batch[:,None,:])
    # compute the loss
    loss = loss_function(pred, y_batch)
    # backward pass
    loss.backward()
    # SGD update
    optimizer.step()

  # Run whole dataset to get statistics -- normally wouldn't do this
  pred_train = model(x_train[:,None,:])
  pred_val = model(x_val[:,None,:])
  _, predicted_train_class = torch.max(pred_train.data, 1)
  _, predicted_val_class = torch.max(pred_val.data, 1)
  errors_train[epoch] = 100 - 100 * (predicted_train_class == y_train).float().sum() / len(y_train)
  errors_val[epoch]= 100 - 100 * (predicted_val_class == y_val).float().sum() / len(y_val)
  losses_train[epoch] = loss_function(pred_train, y_train).item()
  losses_val[epoch]= loss_function(pred_val, y_val).item()
  print(f'Epoch {epoch:5d}, train loss {losses_train[epoch]:.6f}, train error {errors_train[epoch]:3.2f},  val loss {losses_val[epoch]:.6f}, percent error {errors_val[epoch]:3.2f}')

  # tell scheduler to consider updating learning rate
  scheduler.step()

# Plot the results
fig, ax = plt.subplots()
ax.plot(errors_train,'r-',label='train')
ax.plot(errors_val,'b-',label='validation')
ax.set_ylim(0,100); ax.set_xlim(0,n_epoch)
ax.set_xlabel('Epoch'); ax.set_ylabel('Error')
ax.set_title('Part I: Validation Result %3.2f'%(errors_val[-1]))
ax.legend()
plt.show()
# Out:
# Epoch     0, train loss 2.057474, train error 79.43,  val loss 2.060081, percent error 79.00
# Epoch     1, train loss 1.530683, train error 60.58,  val loss 1.565647, percent error 63.60
# Epoch     2, train loss 1.397748, train error 58.42,  val loss 1.425554, percent error 60.60
# Epoch     3, train loss 1.335150, train error 56.17,  val loss 1.344309, percent error 58.50
# Epoch     4, train loss 1.225004, train error 48.65,  val loss 1.256114, percent error 50.80
# Epoch     5, train loss 1.121156, train error 44.97,  val loss 1.139442, percent error 46.80
# Epoch     6, train loss 1.083991, train error 44.92,  val loss 1.142442, percent error 46.70
# Epoch     7, train loss 0.966572, train error 37.58,  val loss 1.014709, percent error 40.50
# Epoch     8, train loss 0.808468, train error 31.78,  val loss 0.860970, percent error 33.50
# Epoch     9, train loss 0.749304, train error 29.38,  val loss 0.830339, percent error 31.60
# Epoch    10, train loss 0.697521, train error 27.40,  val loss 0.767493, percent error 29.10
# Epoch    11, train loss 0.531459, train error 20.95,  val loss 0.620159, percent error 24.10
# Epoch    12, train loss 0.517440, train error 19.85,  val loss 0.611071, percent error 22.90
# Epoch    13, train loss 0.458049, train error 17.90,  val loss 0.564747, percent error 22.20
# Epoch    14, train loss 0.454444, train error 17.47,  val loss 0.562118, percent error 20.20
# Epoch    15, train loss 0.410029, train error 17.03,  val loss 0.549843, percent error 21.60
# Epoch    16, train loss 0.385553, train error 14.32,  val loss 0.534865, percent error 20.00
# Epoch    17, train loss 0.336668, train error 12.70,  val loss 0.444436, percent error 16.70
# Epoch    18, train loss 0.305699, train error 11.80,  val loss 0.476599, percent error 17.30
# Epoch    19, train loss 0.441723, train error 15.85,  val loss 0.584150, percent error 20.20
# Epoch    20, train loss 0.230507, train error 8.55,  val loss 0.402559, percent error 13.30
# Epoch    21, train loss 0.226901, train error 8.10,  val loss 0.408489, percent error 14.00
# Epoch    22, train loss 0.200690, train error 7.25,  val loss 0.393982, percent error 13.30
# Epoch    23, train loss 0.200878, train error 7.40,  val loss 0.409143, percent error 14.70
# Epoch    24, train loss 0.203259, train error 7.53,  val loss 0.402921, percent error 13.80
# Epoch    25, train loss 0.175246, train error 5.93,  val loss 0.374964, percent error 12.80
# Epoch    26, train loss 0.167753, train error 5.88,  val loss 0.410782, percent error 12.90
# Epoch    27, train loss 0.174161, train error 6.45,  val loss 0.416879, percent error 14.40
# Epoch    28, train loss 0.178062, train error 6.72,  val loss 0.411312, percent error 13.70
# Epoch    29, train loss 0.140351, train error 4.65,  val loss 0.364436, percent error 11.50
# Epoch    30, train loss 0.130033, train error 4.05,  val loss 0.392880, percent error 13.50
# Epoch    31, train loss 0.131796, train error 4.40,  val loss 0.373650, percent error 12.40
# Epoch    32, train loss 0.131387, train error 4.07,  val loss 0.367834, percent error 11.40
# Epoch    33, train loss 0.121576, train error 4.12,  val loss 0.384795, percent error 12.60
# Epoch    34, train loss 0.115730, train error 3.75,  val loss 0.378723, percent error 11.50
# Epoch    35, train loss 0.129884, train error 4.68,  val loss 0.412348, percent error 12.50
# Epoch    36, train loss 0.109345, train error 3.65,  val loss 0.412805, percent error 12.50
# Epoch    37, train loss 0.092388, train error 2.97,  val loss 0.377613, percent error 11.40
# Epoch    38, train loss 0.092760, train error 2.88,  val loss 0.401777, percent error 12.30
# Epoch    39, train loss 0.088533, train error 2.95,  val loss 0.378300, percent error 12.00
# Epoch    40, train loss 0.068332, train error 1.93,  val loss 0.361553, percent error 11.80
# Epoch    41, train loss 0.064576, train error 1.60,  val loss 0.360666, percent error 11.50
# Epoch    42, train loss 0.079669, train error 2.55,  val loss 0.395608, percent error 11.50
# Epoch    43, train loss 0.062153, train error 1.93,  val loss 0.375607, percent error 12.20
# Epoch    44, train loss 0.067214, train error 2.00,  val loss 0.374485, percent error 11.00
# Epoch    45, train loss 0.059104, train error 1.62,  val loss 0.376438, percent error 11.50
# Epoch    46, train loss 0.059361, train error 1.78,  val loss 0.374046, percent error 11.80
# Epoch    47, train loss 0.059936, train error 1.80,  val loss 0.383040, percent error 11.40
# Epoch    48, train loss 0.055370, train error 1.43,  val loss 0.387709, percent error 11.70
# Epoch    49, train loss 0.049815, train error 1.10,  val loss 0.373737, percent error 11.50
# Epoch    50, train loss 0.052805, train error 1.43,  val loss 0.379021, percent error 11.40
# Epoch    51, train loss 0.052295, train error 1.32,  val loss 0.394766, percent error 12.00
# Epoch    52, train loss 0.050279, train error 1.25,  val loss 0.388685, percent error 12.30
# Epoch    53, train loss 0.045246, train error 0.90,  val loss 0.378138, percent error 11.50
# Epoch    54, train loss 0.042991, train error 0.85,  val loss 0.383741, percent error 11.00
# Epoch    55, train loss 0.044284, train error 1.03,  val loss 0.382675, percent error 11.00
# Epoch    56, train loss 0.048278, train error 1.22,  val loss 0.402046, percent error 10.90
# Epoch    57, train loss 0.039902, train error 0.85,  val loss 0.386255, percent error 11.00
# Epoch    58, train loss 0.040459, train error 0.88,  val loss 0.394400, percent error 11.50
# Epoch    59, train loss 0.038890, train error 0.80,  val loss 0.387582, percent error 11.30
# Epoch    60, train loss 0.035992, train error 0.70,  val loss 0.389986, percent error 11.20
# Epoch    61, train loss 0.035871, train error 0.62,  val loss 0.394763, percent error 11.10
# Epoch    62, train loss 0.034652, train error 0.57,  val loss 0.397108, percent error 10.90
# Epoch    63, train loss 0.034739, train error 0.55,  val loss 0.390531, percent error 11.30
# Epoch    64, train loss 0.036375, train error 0.57,  val loss 0.397463, percent error 11.20
# Epoch    65, train loss 0.037351, train error 0.72,  val loss 0.398126, percent error 10.60
# Epoch    66, train loss 0.033159, train error 0.40,  val loss 0.406935, percent error 11.00
# Epoch    67, train loss 0.033109, train error 0.53,  val loss 0.399693, percent error 10.90
# Epoch    68, train loss 0.032369, train error 0.40,  val loss 0.400323, percent error 11.00
# Epoch    69, train loss 0.031912, train error 0.55,  val loss 0.401972, percent error 11.30
# Epoch    70, train loss 0.031008, train error 0.38,  val loss 0.405514, percent error 11.20
# Epoch    71, train loss 0.031739, train error 0.40,  val loss 0.406032, percent error 11.40
# Epoch    72, train loss 0.030644, train error 0.35,  val loss 0.401860, percent error 11.10
# Epoch    73, train loss 0.030008, train error 0.35,  val loss 0.411111, percent error 11.10
# Epoch    74, train loss 0.029384, train error 0.30,  val loss 0.409825, percent error 11.00
# Epoch    75, train loss 0.029194, train error 0.40,  val loss 0.412369, percent error 11.10
# Epoch    76, train loss 0.029713, train error 0.40,  val loss 0.410654, percent error 11.10
# Epoch    77, train loss 0.028651, train error 0.35,  val loss 0.414677, percent error 11.40
# Epoch    78, train loss 0.030169, train error 0.45,  val loss 0.415303, percent error 11.10
# Epoch    79, train loss 0.029971, train error 0.32,  val loss 0.425078, percent error 11.30
# Epoch    80, train loss 0.027030, train error 0.25,  val loss 0.414265, percent error 11.20
# Epoch    81, train loss 0.026889, train error 0.28,  val loss 0.417214, percent error 11.00
# Epoch    82, train loss 0.026853, train error 0.22,  val loss 0.418927, percent error 11.10
# Epoch    83, train loss 0.026924, train error 0.22,  val loss 0.419915, percent error 11.30
# Epoch    84, train loss 0.027032, train error 0.30,  val loss 0.421230, percent error 11.20
# Epoch    85, train loss 0.026608, train error 0.28,  val loss 0.418821, percent error 11.00
# Epoch    86, train loss 0.026426, train error 0.20,  val loss 0.422879, percent error 11.00
# Epoch    87, train loss 0.025935, train error 0.22,  val loss 0.420942, percent error 11.10
# Epoch    88, train loss 0.025813, train error 0.22,  val loss 0.421211, percent error 11.10
# Epoch    89, train loss 0.025488, train error 0.28,  val loss 0.421844, percent error 11.00
# Epoch    90, train loss 0.025411, train error 0.22,  val loss 0.422104, percent error 11.10
# Epoch    91, train loss 0.025271, train error 0.20,  val loss 0.423941, percent error 11.00
# Epoch    92, train loss 0.025193, train error 0.22,  val loss 0.422833, percent error 11.00
# Epoch    93, train loss 0.024861, train error 0.22,  val loss 0.425078, percent error 11.10
# Epoch    94, train loss 0.025920, train error 0.28,  val loss 0.427835, percent error 11.30
# Epoch    95, train loss 0.024873, train error 0.22,  val loss 0.430088, percent error 11.40
# Epoch    96, train loss 0.024476, train error 0.25,  val loss 0.424167, percent error 10.80
# Epoch    97, train loss 0.024478, train error 0.22,  val loss 0.426579, percent error 11.00
# Epoch    98, train loss 0.024136, train error 0.22,  val loss 0.428122, percent error 11.00
# Epoch    99, train loss 0.024259, train error 0.22,  val loss 0.428120, percent error 11.20
